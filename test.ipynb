# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers,regularizers
import pandas as pd
import numpy as np

# %%
model=tf.keras.models.load_model("firemodel")

from PIL import ImageTk, Image
import matplotlib.pyplot as plt
import numpy as np

image = Image.open("D:\\chill\\memories\\randonne\\forest.jpg")
image = image.resize((512,512))
plt.imshow(image)
image = np.expand_dims(image, axis=0)
image = np.array(image)
image = 2*(image/255)-1
predection=model.predict(image)
if predection < 0.3:
    print(f"{1-predection[0][0]:.2f}%")
    print("no fire")
else:
    print(f"{predection[0][0]:.2f}%")
    print("fire")
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000187FF39CF70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 93ms/step
# 1.00%
# no fire
